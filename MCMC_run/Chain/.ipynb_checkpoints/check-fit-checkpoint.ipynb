# %%
import numpy as np
import emcee
import corner
from matplotlib import pyplot as plt
from emcee.autocorr import integrated_time

# %%
n_disc = 200 # burn-in
names = ['K0_b_sqr', 'z_pivot', 'Om']
labels =  [r'$K_0b^2_\mathrm{GW}$', r'$z_\mathrm{pivot}$', r'$\Omega_\mathrm{m}$']


filename = "../data/chain/chain1.0.h5"
backend = emcee.backends.HDFBackend(filename, read_only=True)
data = backend.get_chain()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-2-4686c25e23e2> in <module>()
#       6 filename = "../data/chain/chain1.0.h5"
#       7 backend = emcee.backends.HDFBackend(filename, read_only=True)
# ----> 8 data = backend.get_chain()
#
# /home/vardanyan/GWB_MCMC/Chain_1/emcee/backends/backend.pyc in get_chain(self, **kwargs)
#      69
#      70         """
# ---> 71         return self.get_value("chain", **kwargs)
#      72
#      73     def get_blobs(self, **kwargs):
#
# /home/vardanyan/GWB_MCMC/Chain_1/emcee/backends/hdf.pyc in get_value(self, name, flat, thin, discard)
#      96             iteration = g.attrs["iteration"]
#      97             if iteration <= 0:
# ---> 98                 raise AttributeError("You must run the sampler with "
#      99                                      "'store == True' before accessing the "
#     100                                      "results")
#
# AttributeError: You must run the sampler with 'store == True' before accessing the results

# %%
data = backend.get_chain()

print data.shape
for i in xrange(4):
    plt.figure()
    plt.gca().set_xlabel('chain step')
    plt.gca().set_ylabel(r"Position of "+names[i])
    plt.axvline(n_disc, c='r', ls='--')
    plt.plot(data[:, :, i], c='k', alpha=0.1)
    

lnprob = backend.get_log_prob(discard=n_disc)

plt.figure()
plt.gca().set_xlabel('chain step')
plt.gca().set_ylabel(r"max $\log \mathcal{L}$")
plt.plot(lnprob[:, :].max(axis=1), c='k', alpha=0.1)
#plt.gca().set_ylim([-3, 0])
plt.show()
# Out:
# (7549, 13, 4)

# %%
samps = backend.get_chain(flat = True, discard=n_disc)

#Using the familiar getdist:
#;------------------------;
#from getdist import plots, MCSamples
#points = MCSamples(samples=samps,names = names, labels = labels)
#g = plots.getSubplotPlotter()
#g.triangle_plot(points, filled=True)
#;-----------------------;

print samps.shape

corner.corner(samps, labels=labels, show_titles=True, \
              plot_datapoints=False, plot_density=False, \
              quantiles=(0.16, 0.84), levels=(1-np.exp(-0.5),1-np.exp(-2)), \
              fill_contours=True, truths=np.load('data/fparams.npy'))
plt.show()
# Out:
# (95550, 4)

# %%
plt.scatter(samps[:, 0]**2.*samps[:, 1], samps[:, 0])
plt.show()


plt.hist(samps[:,0]**2. * samps[:, 1])
plt.show()
